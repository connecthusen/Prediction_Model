# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
import warnings
warnings.filterwarnings('ignore')
import joblib

# %%
#outliers handling
class IQRClipper(BaseEstimator, TransformerMixin):
    def __init__(self, col='avg_monthly_price'):
        self.col = col
    def fit(self, X, y=None):
        Q1 = X[self.col].quantile(0.25)
        Q3 = X[self.col].quantile(0.75)
        IQR = Q3 - Q1
        self.lower_ = Q1 - 1.5 * IQR
        self.upper_ = Q3 + 1.5 * IQR
        return self
    def transform(self, X):
        df = X.copy()
        df[self.col] = df[self.col].clip(lower=self.lower_, upper=self.upper_)
        return df

# %%
#feature engineering
class FeatureEngineer(BaseEstimator, TransformerMixin):
    def __init__(self, col='avg_monthly_price'):
        self.col = col
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        df = X.copy()
        df['month']     = df.index.month
        df['quarter']   = df.index.quarter
        df['year']      = df.index.year
        df['trend']     = np.arange(len(df))
        df['lag_1']     = df[self.col].shift(1)
        df['lag_2']     = df[self.col].shift(2)
        df['lag_3']     = df[self.col].shift(3)
        df['roll_3']    = df[self.col].shift(1).rolling(3).mean()
        df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
        df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
        df['momentum']  = df[self.col].diff(1)
        df.dropna(inplace=True)
        return df

# %%
#load the model
artifact   = joblib.load("price_model.joblib")
preprocess = artifact['preprocess']
model      = artifact['model']
last_3     = list(artifact['last_3'])    # [price_t-3, price_t-2, price_t-1]
last_trend = artifact['last_trend']
last_date  = artifact['last_date']
FEATURES   = model.named_steps['scaler'].feature_names_in_.tolist()
TARGET     = 'avg_monthly_price'

# %%
#read data
df_raw = pd.read_csv("price_data.csv")
df_raw['date'] = pd.to_datetime(df_raw['date'])
df_raw.set_index('date', inplace=True)
 
df_feat = preprocess.transform(df_raw)
X, y    = df_feat[FEATURES], df_feat[TARGET]
split   = len(df_feat) - 12
X_train, X_test = X.iloc[:split], X.iloc[split:]
y_train, y_test = y.iloc[:split], y.iloc[split:]

#evalution metrics
def evaluate(y_true, y_pred, label):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2   = r2_score(y_true, y_pred)
    print(f"\n {label}")
    print(f"  MAE  : {mae:.2f}")
    print(f"  RMSE : {rmse:.2f}")
    print(f"  MAPE : {mape:.2f}%")
    print(f"  R2   : {r2:.4f}")
 
print("=" * 40)
print(" Model Verification (loaded model)")
print("=" * 40)
evaluate(y_train, model.predict(X_train), "TRAIN")
evaluate(y_test,  model.predict(X_test),  "TEST")
# Out:
# ========================================
#  Model Verification (loaded model)
# ========================================
#
#  TRAIN
#   MAE  : 45.49
#   RMSE : 87.86
#   MAPE : 0.62%
#   R2   : 0.9987
#
#  TEST
#   MAE  : 91.90
#   RMSE : 124.67
#   MAPE : 0.68%
#   R2   : 0.9913

# %%
# Predict NEXT SINGLE MONTH 

next_date = last_date + pd.DateOffset(months=1)
 
# Build one row using real last_3 prices
seed_dates = pd.date_range(end=last_date, periods=3, freq='MS')
df_window  = pd.DataFrame(
    {TARGET: list(last_3) + [last_3[-1]]},
    index = list(seed_dates) + [next_date]
)
 
engineer        = preprocess.named_steps['engineer']
df_eng          = engineer.transform(df_window)
df_eng['trend'] = last_trend + 1
 
next_price = model.predict(df_eng[FEATURES].iloc[[-1]])[0]
 
print("\n" + "=" * 40)
print(" Next Month Prediction")
print("=" * 40)
print(f"  Month : {next_date.strftime('%B %Y')}")
print(f"  Predicted Price : {next_price:.2f}")
# Out:
# ========================================
#  Next Month Prediction
# ========================================
#   Month : October 2025
#   Predicted Price : 15223.94
